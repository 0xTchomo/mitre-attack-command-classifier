# %% [markdown]
# # MITRE ATT&CK Command Classification — DL Baseline (Tokenizer + LSTM)
#
# This notebook trains a deep learning baseline using:
# - Keras Tokenizer (top 5k words)
# - Sequence padding (max length 20)
# - LSTM classifier
#
# Artifacts are saved under `models/`.

# %%
import sys
from pathlib import Path

def find_repo_root(start: Path) -> Path:
    for p in [start] + list(start.parents):
        if (p / "command_classifier").exists() and (p / "data").exists():
            return p
    return start

ROOT = find_repo_root(Path.cwd())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Repo root:", ROOT)

# %% [markdown]
# ## Train & evaluate (no code duplication)
#
# We call the training script directly.

# %%
# !python -m command_classifier.train_lstm

# %% [markdown]
#  The trained model is saved to `models/lstm.keras`.
